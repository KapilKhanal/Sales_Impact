# %%
import pandas as pd
import numpy as np

import time, warnings
import datetime as dt

import sklearn.cluster as cluster
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

from sklearn.metrics import silhouette_samples, silhouette_score
from scipy.spatial.distance import cdist

import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
# Causal impact imports
from IPython.core.pylabtools import figsize
figsize(14, 6)
import statsmodels as sm
from statsmodels.tsa.statespace.structural import UnobservedComponents
from statsmodels.tsa.arima_process import ArmaProcess
from causalimpact import CausalImpact

# %%
df = pd.read_excel("Online_Retail.xlsx")
test = pd.read_excel("onlineretail.xlsx")

# %%
df.shape, test.shape
# Out:
# ((541909, 8), (541909, 8))

# %%
df2 = df.groupby(['CustomerID','Country']).agg(['count'])
test2 = test.groupby(['CustomerID','Country']).agg(['count'])

# %%
df.groupby(['CustomerID','Country']).agg(['count'])
# Out:
#                           InvoiceNo StockCode Description Quantity  \
#                               count     count       count    count
# CustomerID Country
# 12346.0    United Kingdom         2         2           2        2
# 12347.0    Iceland              182       182         182      182
# 12348.0    Finland               31        31          31       31
# 12349.0    Italy                 73        73          73       73
# 12350.0    Norway                17        17          17       17
# ...                             ...       ...         ...      ...
# 18280.0    United Kingdom        10        10          10       10
# 18281.0    United Kingdom         7         7           7        7
# 18282.0    United Kingdom        13        13          13       13
# 18283.0    United Kingdom       756       756         756      756
# 18287.0    United Kingdom        70        70          70       70
#
#                           InvoiceDate UnitPrice
#                                 count     count
# CustomerID Country
# 12346.0    United Kingdom           2         2
# 12347.0    Iceland                182       182
# 12348.0    Finland                 31        31
# 12349.0    Italy                   73        73
# 12350.0    Norway                  17        17
# ...                               ...       ...
# 18280.0    United Kingdom          10        10
# 18281.0    United Kingdom           7         7
# 18282.0    United Kingdom          13        13
# 18283.0    United Kingdom         756       756
# 18287.0    United Kingdom          70        70
#
# [4380 rows x 6 columns]

# %%
df3 = df2.reset_index()

# %%
df3 = df3[['CustomerID','Country']]

# %%
df3.CustomerID.nunique()
# Out:
# 4372

# %%
df3
# Out:
#      CustomerID         Country
#
# 0       12346.0  United Kingdom
# 1       12347.0         Iceland
# 2       12348.0         Finland
# 3       12349.0           Italy
# 4       12350.0          Norway
# ...         ...             ...
# 4375    18280.0  United Kingdom
# 4376    18281.0  United Kingdom
# 4377    18282.0  United Kingdom
# 4378    18283.0  United Kingdom
# 4379    18287.0  United Kingdom
#
# [4380 rows x 2 columns]

# %%
# Customer table
#df3.to_csv('CustomerTable.csv')

# %%
# Transaction Table
dft = df.groupby(['InvoiceNo','InvoiceDate','CustomerID','Country','StockCode','Quantity']).agg(['count'])

# %%
dft1 = dft.reset_index()

# %%
# final transaction table
dft2 = dft1[['InvoiceNo','InvoiceDate','CustomerID','Country','StockCode','Quantity']]

# %%
dft2
# Out:
#        InvoiceNo         InvoiceDate CustomerID         Country StockCode  \
#
# 0         536365 2010-12-01 08:26:00    17850.0  United Kingdom     21730
# 1         536365 2010-12-01 08:26:00    17850.0  United Kingdom     22752
# 2         536365 2010-12-01 08:26:00    17850.0  United Kingdom     71053
# 3         536365 2010-12-01 08:26:00    17850.0  United Kingdom    84029E
# 4         536365 2010-12-01 08:26:00    17850.0  United Kingdom    84029G
# ...          ...                 ...        ...             ...       ...
# 401544   C581490 2011-12-09 09:57:00    14397.0  United Kingdom     23144
# 401545   C581499 2011-12-09 10:28:00    15498.0  United Kingdom         M
# 401546   C581568 2011-12-09 11:57:00    15311.0  United Kingdom     21258
# 401547   C581569 2011-12-09 11:58:00    17315.0  United Kingdom     20979
# 401548   C581569 2011-12-09 11:58:00    17315.0  United Kingdom     84978
#
#        Quantity
#
# 0             6
# 1             2
# 2             6
# 3             6
# 4             6
# ...         ...
# 401544      -11
# 401545       -1
# 401546       -5
# 401547       -5
# 401548       -1
#
# [401549 rows x 6 columns]

# %%
dft2.to_csv('TransactionsTable.csv')

# %%
# Item table
dfI = df.groupby(['StockCode','Description','UnitPrice']).agg(['count'])

dfI1 = dfI.reset_index()

dfI2 = dfI1[['StockCode','Description','UnitPrice']]

# %%
testI = test.groupby(['StockCode','Description']).agg({'UnitPrice':np.mean})
testI1 = testI.reset_index()
testI2 = testI1[['StockCode','Description','UnitPrice']]

# %%
testI2.to_csv('ItemsTable.csv')

# %%
dfI2.head()
# Out:
#   StockCode                  Description UnitPrice
#
# 0     10002  INFLATABLE POLITICAL GLOBE       0.85
# 1     10002  INFLATABLE POLITICAL GLOBE       1.63
# 2     10002  INFLATABLE POLITICAL GLOBE       1.66
# 3     10080     GROOVY CACTUS INFLATABLE      0.39
# 4     10080     GROOVY CACTUS INFLATABLE      0.85

# %%
testI2.head()
# Out:
#   StockCode                  Description  UnitPrice
# 0     10002  INFLATABLE POLITICAL GLOBE    1.086620
# 1     10080     GROOVY CACTUS INFLATABLE   0.410909
# 2     10080                        check   0.000000
# 3     10120                 DOGGY RUBBER   0.210000
# 4     10125      MINI FUNKY DESIGN TAPES   0.859681

# %%
#dfI2.to_csv('ItemsTable.csv')

# %%
dfI2
# Out:
#        StockCode                  Description CustomerID         Country  \
#
# 0          10002  INFLATABLE POLITICAL GLOBE     12451.0     Switzerland
# 1          10002  INFLATABLE POLITICAL GLOBE     12510.0           Spain
# 2          10002  INFLATABLE POLITICAL GLOBE     12583.0          France
# 3          10002  INFLATABLE POLITICAL GLOBE     12637.0          France
# 4          10002  INFLATABLE POLITICAL GLOBE     12673.0         Germany
# ...          ...                          ...        ...             ...
# 277412      POST                      POSTAGE    17935.0  United Kingdom
# 277413      POST                      POSTAGE    17940.0  United Kingdom
# 277414      POST                      POSTAGE    18223.0  United Kingdom
# 277415      POST                      POSTAGE    18257.0  United Kingdom
# 277416      POST                      POSTAGE    18270.0  United Kingdom
#
#        UnitPrice
#
# 0           0.85
# 1           0.85
# 2           0.85
# 3           0.85
# 4           0.85
# ...          ...
# 277412      2.90
# 277413     75.00
# 277414      2.84
# 277415      8.65
# 277416      5.95
#
# [277417 rows x 5 columns]

# %%
len(df)
# Out:
# 541909

# %%
dfs1 = dft2.merge(df3, on=['CustomerID','Country'], how='left')

# %%
dfs1
# Out:
#        InvoiceNo         InvoiceDate CustomerID         Country StockCode  \
#
# 0         536365 2010-12-01 08:26:00    17850.0  United Kingdom     21730
# 1         536365 2010-12-01 08:26:00    17850.0  United Kingdom     22752
# 2         536365 2010-12-01 08:26:00    17850.0  United Kingdom     71053
# 3         536365 2010-12-01 08:26:00    17850.0  United Kingdom    84029E
# 4         536365 2010-12-01 08:26:00    17850.0  United Kingdom    84029G
# ...          ...                 ...        ...             ...       ...
# 401544   C581490 2011-12-09 09:57:00    14397.0  United Kingdom     23144
# 401545   C581499 2011-12-09 10:28:00    15498.0  United Kingdom         M
# 401546   C581568 2011-12-09 11:57:00    15311.0  United Kingdom     21258
# 401547   C581569 2011-12-09 11:58:00    17315.0  United Kingdom     20979
# 401548   C581569 2011-12-09 11:58:00    17315.0  United Kingdom     84978
#
#        Quantity
#
# 0             6
# 1             2
# 2             6
# 3             6
# 4             6
# ...         ...
# 401544      -11
# 401545       -1
# 401546       -5
# 401547       -5
# 401548       -1
#
# [401549 rows x 6 columns]

# %%
dfs2 = dfs1.merge(testI2, on=['StockCode'], how='left')

# %%
dfs2
# Out:
#        StockCode (InvoiceNo, )     (InvoiceDate, )  (CustomerID, )  \
# 0          21730        536365 2010-12-01 08:26:00         17850.0
# 1          22752        536365 2010-12-01 08:26:00         17850.0
# 2          71053        536365 2010-12-01 08:26:00         17850.0
# 3          71053        536365 2010-12-01 08:26:00         17850.0
# 4         84029E        536365 2010-12-01 08:26:00         17850.0
# ...          ...           ...                 ...             ...
# 532976         M       C581499 2011-12-09 10:28:00         15498.0
# 532977     21258       C581568 2011-12-09 11:57:00         15311.0
# 532978     21258       C581568 2011-12-09 11:57:00         15311.0
# 532979     20979       C581569 2011-12-09 11:58:00         17315.0
# 532980     84978       C581569 2011-12-09 11:58:00         17315.0
#
#            (Country, ) (StockCode, )  (Quantity, )  \
# 0       United Kingdom         21730             6
# 1       United Kingdom         22752             2
# 2       United Kingdom         71053             6
# 3       United Kingdom         71053             6
# 4       United Kingdom        84029E             6
# ...                ...           ...           ...
# 532976  United Kingdom             M            -1
# 532977  United Kingdom         21258            -5
# 532978  United Kingdom         21258            -5
# 532979  United Kingdom         20979            -5
# 532980  United Kingdom         84978            -1
#
#                               Description   UnitPrice
# 0       GLASS STAR FROSTED T-LIGHT HOLDER    5.322837
# 1            SET 7 BABUSHKA NESTING BOXES    9.767352
# 2                     WHITE METAL LANTERN    4.627866
# 3            WHITE MOROCCAN METAL LANTERN    6.595185
# 4          RED WOOLLY HOTTIE WHITE HEART.    5.102071
# ...                                   ...         ...
# 532976                             Manual  375.566392
# 532977                                  ?    0.000000
# 532978         VICTORIAN SEWING BOX LARGE   16.494451
# 532979      36 PENCILS TUBE RED RETROSPOT    1.569101
# 532980   HANGING HEART JAR T-LIGHT HOLDER    1.471043
#
# [532981 rows x 9 columns]

# %%
dfs2.groupby(['CustomerID','Country']).agg(count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-10751985b394> in <module>
# ----> 1 dfs2.groupby(['CustomerID','Country']).agg(count)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'CustomerID'

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]
